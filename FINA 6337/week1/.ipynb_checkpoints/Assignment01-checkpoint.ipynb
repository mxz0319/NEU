# %% [markdown]
# The data for this assignment consists of monthly observations on the prices of the largest 136 stocks in Australia from Dec 1999 to Jun 2014. You will need to place the data file in the same folder (location) as this notebook.
#
# Consider a portfolio constructed by holding <u>one share in each stock</u> in the dataset that has a price recorded at every time period. We'll use $P_{it}$ to denote the price of the $i^{\text th}$ stock at time $t$ and $P_t$ to denote the price of the portfolio at time $t$.

# %%
import os
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# Make sure your data is in the same folder as this notebook
assert os.path.isfile('./AusFirms.csv'), 'Data file Missing!'

# %%
file = os.path.basename('./AusFirms.csv')
ausFirms = pd.read_csv(file, parse_dates = ['date'], date_format='%m/%d/%y')
ausFirms.drop(columns=['rf', 'mkt'], inplace=True)
ausFirms.set_index('date', inplace=True)

# %% [markdown]
# ### RUN THE 3 CELLS ABOVE BUT PLEASE DON'T MODIFY ANYTHING ABOVE THIS LINE

# %% [markdown]
# #### 1. Delete any stock that has missing observations.

# %%
# Enter your code here
ausFirms = ausFirms.dropna(axis=1)
ausFirms
# Out:
#               p2    p5     p7      p9     p10     p11        p12    p14  \
# date
# 1999-12-31  0.69  3.85  20.60   7.100  16.291   2.160  10.680000  3.360
# 2000-01-31  0.69  3.70  24.08   6.550  15.200   1.960  10.550000  3.320
# 2000-02-29  0.49  3.78  17.85   6.000  14.791   1.610  10.010000  3.421
# 2000-03-31  0.49  3.17  15.36   5.708  15.560   1.575  10.400000  3.208
# 2000-04-28  0.45  3.20  15.27   5.070  15.000   1.440  11.840000  3.230
# ...          ...   ...    ...     ...     ...     ...        ...    ...
# 2014-02-28  4.18  8.38   4.98  10.110   4.830  18.150  32.139999  7.310
# 2014-03-31  4.01  8.70   5.38  10.390   4.980  18.410  33.060001  7.270
# 2014-04-30  3.91  8.80   5.03  10.290   5.050  18.090  34.470001  7.200
# 2014-05-30  3.37  9.59   5.31  10.610   5.290  19.250  33.490002  7.360
# 2014-06-30  3.45  9.33   5.26  10.430   5.300  19.830  33.340000  7.630
#
#               p15        p16  ...      p122   p123   p124  p125  p130   p131  \
# date                          ...
# 1999-12-31  2.680  11.850000  ...  3.100000  7.080  8.160  5.50  2.12  2.820
# 2000-01-31  2.450  12.700000  ...  2.400000  6.520  7.800  6.05  1.90  2.711
# 2000-02-29  2.500  15.188000  ...  2.650000  6.780  7.642  6.70  1.75  2.660
# 2000-03-31  2.200  13.800000  ...  2.700000  7.399  7.600  8.73  1.31  2.783
# 2000-04-28  2.100  12.700000  ...  3.100000  7.190  7.340  8.20  1.41  2.740
# ...           ...        ...  ...       ...    ...    ...   ...   ...    ...
# 2014-02-28  0.865  37.560001  ...  7.070000  2.340  5.050  5.32  6.45  7.430
# 2014-03-31  0.975  36.070000  ...  7.260000  2.290  5.080  5.20  7.02  6.970
# 2014-04-30  1.050  35.540001  ...  7.393911  2.550  5.220  5.29  6.75  7.050
# 2014-05-30  1.125  35.980000  ...  7.430000  2.450  5.340  5.42  6.56  8.240
# 2014-06-30  1.280  35.639999  ...  7.390000  2.470  5.210  5.10  6.84  7.360
#
#                  p132       p133       p135       p136
# date
# 1999-12-31  10.310000  12.370000   5.150000  11.450000
# 2000-01-31  10.642000  12.450000   4.870000  11.610000
# 2000-02-29  10.400000  12.394000   4.990000   9.300000
# 2000-03-31  10.313000  11.665000   5.110000   9.900000
# 2000-04-28  10.930000  11.919000   5.762000  10.590000
# ...               ...        ...        ...        ...
# 2014-02-28  33.470001  42.950001  36.070000  37.950001
# 2014-03-31  34.560001  41.189999  35.720001  39.020000
# 2014-04-30  35.119999  42.709999  37.320000  40.799999
# 2014-05-30  34.419998  43.360001  37.529999  42.169998
# 2014-06-30  33.880001  41.840000  35.220001  41.070000
#
# [175 rows x 81 columns]

# %% [markdown]
# #### 2. How many stocks are remaining?

# %%
# Enter your code here
num = len(ausFirms.columns)
num
# Out:
# 81

# %% [markdown]
# #### 3. Create a new series called $P$ that records the portfolio value for each date. Since you have one share of each stock in the portfolio, you just need to add all the prices.

# %%
# Enter your code here
P = ausFirms.sum(axis='columns')
P
# Out:
# date
# 1999-12-31     649.330003
# 2000-01-31     638.704006
# 2000-02-29     639.325378
# 2000-03-31     631.475002
# 2000-04-28     637.859003
#                  ...
# 2014-02-28    1335.335001
# 2014-03-31    1329.045008
# 2014-04-30    1331.853919
# 2014-05-30    1340.594982
# 2014-06-30    1319.470007
# Length: 175, dtype: float64

# %% [markdown]
# #### 4. Let's say the starting date is 1 and the ending date is $T$. For the portfolio, calculate the simple return: $\frac{P_T}{P_1}-1$; and the log return: $\log\left(\frac{P_T}{P_1 }\right)$.

# %%
# Your code here (enter your code inside the { . } for each return)
print(f'Simple return = { P[-1]/P[0]-1 }; Log return = { np.log(P[-1]/P[0]) }')
# Out:
# Simple return = 1.0320484213714782; Log return = 0.709044358847417

# %% [markdown]
# #### 5. Calculate the portfolio weights: $\text{w}_{it} = \frac{P_{it}}{P_t}$.
#
# If you use the *divide* method from Pandas, this is just one line and you will end up with a dataframe the same size as ausFirms.

# %%
weight = ausFirms.div(P, axis=0)
weight
# Out:
#                   p2        p5        p7        p9       p10       p11  \
# date
# 1999-12-31  0.001063  0.005929  0.031725  0.010934  0.025089  0.003327
# 2000-01-31  0.001080  0.005793  0.037701  0.010255  0.023798  0.003069
# 2000-02-29  0.000766  0.005912  0.027920  0.009385  0.023135  0.002518
# 2000-03-31  0.000776  0.005020  0.024324  0.009039  0.024641  0.002494
# 2000-04-28  0.000705  0.005017  0.023939  0.007948  0.023516  0.002258
# ...              ...       ...       ...       ...       ...       ...
# 2014-02-28  0.003130  0.006276  0.003729  0.007571  0.003617  0.013592
# 2014-03-31  0.003017  0.006546  0.004048  0.007818  0.003747  0.013852
# 2014-04-30  0.002936  0.006607  0.003777  0.007726  0.003792  0.013583
# 2014-05-30  0.002514  0.007154  0.003961  0.007914  0.003946  0.014359
# 2014-06-30  0.002615  0.007071  0.003986  0.007905  0.004017  0.015029
#
#                  p12       p14       p15       p16  ...      p122      p123  \
# date                                                ...
# 1999-12-31  0.016448  0.005175  0.004127  0.018250  ...  0.004774  0.010904
# 2000-01-31  0.016518  0.005198  0.003836  0.019884  ...  0.003758  0.010208
# 2000-02-29  0.015657  0.005351  0.003910  0.023756  ...  0.004145  0.010605
# 2000-03-31  0.016469  0.005080  0.003484  0.021854  ...  0.004276  0.011717
# 2000-04-28  0.018562  0.005064  0.003292  0.019910  ...  0.004860  0.011272
# ...              ...       ...       ...       ...  ...       ...       ...
# 2014-02-28  0.024069  0.005474  0.000648  0.028128  ...  0.005295  0.001752
# 2014-03-31  0.024875  0.005470  0.000734  0.027140  ...  0.005463  0.001723
# 2014-04-30  0.025881  0.005406  0.000788  0.026685  ...  0.005552  0.001915
# 2014-05-30  0.024981  0.005490  0.000839  0.026839  ...  0.005542  0.001828
# 2014-06-30  0.025268  0.005783  0.000970  0.027011  ...  0.005601  0.001872
#
#                 p124      p125      p130      p131      p132      p133  \
# date
# 1999-12-31  0.012567  0.008470  0.003265  0.004343  0.015878  0.019050
# 2000-01-31  0.012212  0.009472  0.002975  0.004245  0.016662  0.019493
# 2000-02-29  0.011953  0.010480  0.002737  0.004161  0.016267  0.019386
# 2000-03-31  0.012035  0.013825  0.002075  0.004407  0.016332  0.018473
# 2000-04-28  0.011507  0.012856  0.002211  0.004296  0.017135  0.018686
# ...              ...       ...       ...       ...       ...       ...
# 2014-02-28  0.003782  0.003984  0.004830  0.005564  0.025065  0.032164
# 2014-03-31  0.003822  0.003913  0.005282  0.005244  0.026004  0.030992
# 2014-04-30  0.003919  0.003972  0.005068  0.005293  0.026369  0.032068
# 2014-05-30  0.003983  0.004043  0.004893  0.006147  0.025675  0.032344
# 2014-06-30  0.003949  0.003865  0.005184  0.005578  0.025677  0.031710
#
#                 p135      p136
# date
# 1999-12-31  0.007931  0.017634
# 2000-01-31  0.007625  0.018177
# 2000-02-29  0.007805  0.014547
# 2000-03-31  0.008092  0.015678
# 2000-04-28  0.009033  0.016602
# ...              ...       ...
# 2014-02-28  0.027012  0.028420
# 2014-03-31  0.026876  0.029359
# 2014-04-30  0.028021  0.030634
# 2014-05-30  0.027995  0.031456
# 2014-06-30  0.026693  0.031126
#
# [175 rows x 81 columns]

# %% [markdown]
# #### 6. Calculate the simple returns for each stock: $R_{it} = \frac{P_{it}}{P_{i,t-1}}-1$ and the log returns for each stock: $r_{it} = \log\frac{P_{it}}{P_{i,t-1}}$.
#
# You only need one line for each return. To get $P_{i,t-1}$, you can use the *shift* method in Pandas.

# %%
# Your code here
simple_return = ausFirms.div(ausFirms.shift(), axis=0).sub(1)
log_return = np.log(ausFirms.div(ausFirms.shift(), axis=0))

# %% [markdown]
# #### 7. Now calculate the portfolio returns as follows:
# - For simple returns: $R_{Pt} = w_{1,t-1}R_{1t} + w_{2,t-1}R_{2t} + \cdots + w_{n,t-1}R_{nt}$
# - For log returns: $r_{Pt} = \log (w_{1,t-1}e^{r_{1t}} + w_{2,t-1}e^{r_{2t}} + \cdots + w_{n,t-1}e^{r_{nt}})$
#
# Note that the time index on the weights is one period behind the returns.

# %%
# Your code here (one line for each type of return). After calculating the returns, remove the first row because it is not valid.
simple_portfolio_returns = weight.mul(simple_return).dropna().sum(axis=1)
log_portfolio_returns = np.log(weight.shift().mul(np.exp(log_return)).dropna().sum(axis=1))

# %% [markdown]
# #### 8. Plot the portfolio return series - simple and log

# %%
# Both plots on the same figure. Use two different linestyles and include a legend.
simple_portfolio_returns.plot(label='Simple Return')
log_portfolio_returns.plot(label='Log Return')
plt.legend()

# %% [markdown]
# #### 9. For each stock in the portfolio, calculate the excess kurtosis of the log returns. Then, create a histogram of the kurtosis values.
#
# You can use the *kurtosis* function in scipy for this. The result from this function should be an array of kurtosis values. Then, create a histogram from this array. You can do this entire step in one line if you want to.

# %%
# Your code here. 
from scipy.stats import kurtosis
plt.hist(kurtosis(log_return.dropna())+3)
# Out:
# (array([63.,  7.,  3.,  1.,  1.,  2.,  2.,  1.,  0.,  1.]),
#  array([ 3.36432878, 12.97520218, 22.58607558, 32.19694898, 41.80782238,
#         51.41869578, 61.02956918, 70.64044258, 80.25131597, 89.86218937,
#         99.47306277]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# What do you conclude about the distributions of stock returns from the histogram you've just created? Enter your answer in the cell below.

# %% [markdown]
# The histogram of the distributions indicate a high kurtosis, shows a thicker tails and a low even distribution. The numbers all postive kurtosis.

# %% [markdown]
# #### 9a. Now calculate the excess kurtosis of the portfolio log return.
#
# You should see a big difference between the kurtosis of a typical stock return and the kurtosis of the portfolio. This is one reason why portfolio returns can often be approximated using a normal distribution but individual stock returns cannot.

# %%
# Your code here
kurtosis(log_portfolio_returns)
# Out:
# 0.8001925120930911

# %% [markdown]
# #### 10. Calculate autocorrelation function over 6 lags for the portfolio log return.
#
# You can use the *acf* function in statsmodels to make this easy.

# %%
# Your code here.
sm.tsa.acf(log_portfolio_returns, nlags=6)
# Out:
# array([1.        , 0.14872526, 0.09726622, 0.17614756, 0.09995621,
#        0.00225414, 0.00175506])

# %% [markdown]
# In class, we saw an example where the DM/USD exchange rate had very low autocorrelation values and we took that as evidence of market efficiency. What do you observe here? Enter your answer in the cell below.

# %% [markdown]
# We can see some of the exchange autocorrelation values are really low or even close to zero suggests that the exchage rate's current value is not predictable by its past values. The other higher autocorrelation values suggest that the portfolio has an increasing trend at begining and face a slowly decreasing to the end.
