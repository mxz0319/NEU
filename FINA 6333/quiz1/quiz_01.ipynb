# %%
pip install otter-grader
# Out:
# Collecting otter-grader
#   Downloading otter_grader-4.2.1-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 kB 21.7 MB/s eta 0:00:00
# Collecting nbformat
#   Downloading nbformat-5.7.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 kB 19.8 MB/s eta 0:00:00
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 77.8 MB/s eta 0:00:00
# Collecting ipython
#   Downloading ipython-8.8.0-py3-none-any.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.8/775.8 kB 87.3 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 101.6 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-0.8.0-py2.py3-none-any.whl (19 kB)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 27.9 MB/s eta 0:00:00
# Collecting jupytext
#   Downloading jupytext-1.14.4-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 58.1 MB/s eta 0:00:00
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.72.0-py2.py3-none-any.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 110.4 MB/s eta 0:00:0000:0100:01
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting python-on-whales
#   Downloading python_on_whales-0.56.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 26.1 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 29.9 MB/s eta 0:00:00
# Collecting wrapt
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 18.3 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 35.0 MB/s eta 0:00:00
# Collecting fica>=0.2.0
#   Downloading fica-0.2.2-py3-none-any.whl (11 kB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 15.1 MB/s eta 0:00:00
# Collecting sphinx
#   Downloading sphinx-6.1.3-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 106.0 MB/s eta 0:00:00
# Collecting docutils
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 81.7 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 32.9 MB/s eta 0:00:00
# Collecting google-auth<3.0.0dev,>=1.19.0
#   Downloading google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 44.5 MB/s eta 0:00:00
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.21.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 28.7 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting traitlets>=5
#   Downloading traitlets-5.8.1-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 25.8 MB/s eta 0:00:00
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 16.7 MB/s eta 0:00:00
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting stack-data
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 111.0 MB/s eta 0:00:00
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pygments>=2.4.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 93.1 MB/s eta 0:00:00
# Collecting prompt-toolkit<3.1.0,>=3.0.11
#   Downloading prompt_toolkit-3.0.36-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.4/386.4 kB 57.5 MB/s eta 0:00:00
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting markdown-it-py<3.0.0,>=1.0.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 16.3 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 15.0 MB/s eta 0:00:00
# Collecting jupyter-core
#   Downloading jupyter_core-5.1.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 20.5 MB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 20.6 MB/s eta 0:00:00
# Collecting numpy>=1.20.3
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 86.6 MB/s eta 0:00:0000:0100:01
# Collecting pytz>=2020.1
#   Downloading pytz-2022.7-py2.py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 67.7 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 57.9 MB/s eta 0:00:00
# Collecting typer>=0.4.1
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 17.6 MB/s eta 0:00:00
# Collecting pydantic>=1.5
#   Downloading pydantic-1.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 117.8 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 38.0 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 40.0 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 18.7 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 43.4 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 66.2 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 27.0 MB/s eta 0:00:00
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 29.8 MB/s eta 0:00:00
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 27.4 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 20.8 MB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 12.1 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 33.1 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-2.6.2-py3-none-any.whl (14 kB)
# Collecting snowballstemmer>=2.0
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 22.8 MB/s eta 0:00:00
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib.applehelp-1.0.3-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 22.4 MB/s eta 0:00:00
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 18.1 MB/s eta 0:00:00
# Collecting babel>=2.9
#   Downloading Babel-2.11.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 114.9 MB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 25.5 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 18.8 MB/s eta 0:00:00
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting importlib-metadata>=4.8
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting packaging>=21.0
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 13.1 MB/s eta 0:00:00
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 18.2 MB/s eta 0:00:00
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting pure-eval
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens>=2.1.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting executing>=1.2.0
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 16.9 MB/s eta 0:00:00
# Installing collected packages: wcwidth, snowballstemmer, pytz, pyasn1, pure-eval, ptyprocess, pickleshare, fastjsonschema, executing, backcall, alabaster, zipp, wrapt, urllib3, uritemplate, typing-extensions, traitlets, tqdm, toml, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, six, rsa, PyYAML, pyrsistent, pyparsing, pygments, pyasn1-modules, protobuf, prompt-toolkit, platformdirs, pkgutil-resolve-name, pexpect, parso, packaging, oauthlib, numpy, mdurl, MarkupSafe, imagesize, idna, docutils, dill, decorator, click, charset-normalizer, certifi, cachetools, babel, attrs, typer, requests, python-dateutil, pydantic, matplotlib-inline, markdown-it-py, jupyter-core, jinja2, jedi, importlib-resources, importlib-metadata, httplib2, googleapis-common-protos, google-auth, asttokens, stack-data, sphinx, requests-oauthlib, python-on-whales, pandas, mdit-py-plugins, jsonschema, google-auth-httplib2, google-api-core, nbformat, ipython, google-auth-oauthlib, google-api-python-client, fica, jupytext, otter-grader
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.12 which is incompatible.
# tensorboard 2.9.1 requires google-auth-oauthlib<0.5,>=0.4.1, but you have google-auth-oauthlib 0.8.0 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.12 which is incompatible.
# redshift-connector 2.0.908 requires pytz<2022.2,>=2020.1, but you have pytz 2022.7 which is incompatible.
# redshift-connector 2.0.908 requires requests<2.28.1,>=2.23.0, but you have requests 2.28.1 which is incompatible.
# pandas-profiling 3.4.0 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.1 which is incompatible.
# mlflow 2.0.1 requires importlib-metadata!=4.7.0,<6,>=3.7.0, but you have importlib-metadata 6.0.0 which is incompatible.
# mlflow 2.0.1 requires packaging<22, but you have packaging 23.0 which is incompatible.
# jsonrpcserver 5.0.5 requires jsonschema<4, but you have jsonschema 4.17.3 which is incompatible.
# bertopic 0.12.0 requires pyyaml<6.0, but you have pyyaml 6.0 which is incompatible.
# awscli 1.25.61 requires docutils<0.17,>=0.10, but you have docutils 0.19 which is incompatible.
# awscli 1.25.61 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# awscli 1.25.61 requires rsa<4.8,>=3.1.2, but you have rsa 4.9 which is incompatible.
# pythonwhat 2.23.1 requires asttokens~=1.1.10, but you have asttokens 2.2.1 which is incompatible.
# pythonwhat 2.23.1 requires dill~=0.2.7.1, but you have dill 0.3.6 which is incompatible.
# pythonwhat 2.23.1 requires jinja2~=2.10, but you have jinja2 3.1.2 which is incompatible.
# protowhat 2.0.1 requires jinja2~=2.10, but you have jinja2 3.1.2 which is incompatible.
# Successfully installed MarkupSafe-2.1.1 PyYAML-6.0 alabaster-0.7.12 asttokens-2.2.1 attrs-22.2.0 babel-2.11.0 backcall-0.2.0 cachetools-5.2.1 certifi-2022.12.7 charset-normalizer-2.1.1 click-8.1.3 decorator-5.1.1 dill-0.3.6 docutils-0.19 executing-1.2.0 fastjsonschema-2.16.2 fica-0.2.2 google-api-core-2.11.0 google-api-python-client-2.72.0 google-auth-2.16.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-0.8.0 googleapis-common-protos-1.58.0 httplib2-0.21.0 idna-3.4 imagesize-1.4.1 importlib-metadata-6.0.0 importlib-resources-5.10.2 ipython-8.8.0 jedi-0.18.2 jinja2-3.1.2 jsonschema-4.17.3 jupyter-core-5.1.3 jupytext-1.14.4 markdown-it-py-2.1.0 matplotlib-inline-0.1.6 mdit-py-plugins-0.3.3 mdurl-0.1.2 nbformat-5.7.1 numpy-1.24.1 oauthlib-3.2.2 otter-grader-4.2.1 packaging-23.0 pandas-1.5.2 parso-0.8.3 pexpect-4.8.0 pickleshare-0.7.5 pkgutil-resolve-name-1.3.10 platformdirs-2.6.2 prompt-toolkit-3.0.36 protobuf-4.21.12 ptyprocess-0.7.0 pure-eval-0.2.2 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydantic-1.10.4 pygments-2.14.0 pyparsing-3.0.9 pyrsistent-0.19.3 python-dateutil-2.8.2 python-on-whales-0.56.0 pytz-2022.7 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 six-1.16.0 snowballstemmer-2.2.0 sphinx-6.1.3 sphinxcontrib-applehelp-1.0.3 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 stack-data-0.6.2 toml-0.10.2 tqdm-4.64.1 traitlets-5.8.1 typer-0.7.0 typing-extensions-4.4.0 uritemplate-4.1.1 urllib3-1.26.13 wcwidth-0.2.5 wrapt-1.14.1 zipp-3.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize Otter
import otter
grader = otter.Notebook("quiz_01.ipynb")

# %% [markdown]
# # Quiz 1

# %% [markdown]
# ## Instructions
#
# 1. After you answer a question, you should run its public tests.
# 1. After you answer every question, you should:
#     1. Restart your kernel and clear all output
#     1. Run up to the last cell
#     1. Save your notebook
#     1. Run the last cell to create a .zip file for Gradescope
#     1. Upload this .zip file to Gradescope
#     1. ***Make sure your local autograder results match your Gradescope autograder results***
# 1. This quiz has public and hidden tests:
#     1. Public tests check if your answers are the correct types and shapes, but they may not check if your answers are exactly correct
#     1. Hidden tests check if your answers are exactly correct, but their results are not available until after the due date
# 1. You may ask technical questions on Canvas Discussions, but the quiz is an individual effort.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Question 1

# %% [markdown]
# Create a list named `list_1` that contains the squares for integers from 1 to 100.
# The first and last values in `list_1` should be $1^2 = 1$ and $100^2 = 10,000$, respectively.
#
# _Points:_ 30

# %%
list_1 = []
for i in range(1,101):
    list_1.append(i**2)
print(list_1)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801, 10000]

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!
# q1 - 1 message: list_1 is the correct type (+10 pts)
# q1 - 2 message: list_1 is the correct length (+10 pts)
# q1 - 3 message: list_1 has all correct values (+10 pts)

# %% [markdown]
# ### Question 2

# %% [markdown]
# Create an integer `int_2` that contains the sum of squared integers from 1 to 100 inclusive.
# This `int_2` contains the sum of the values in `list_1` from question 1.
#
# _Points:_ 30

# %%
int_2 = 0
for i in list_1:
    int_2+=i
print(int_2)
# Out:
# 338350

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!
# q2 - 1 message: int_2 is the correct type (+10 pts)
# q2 - 2 message: int_2 is positive (+10 pts)
# q2 - 3 message: int_2 is the correct value (+10 pts)

# %% [markdown]
# ### Question 3

# %% [markdown]
# Write a function `fun_3` that sums that squares of integers between its arguments `start` and `stop` inclusive.
# If `start=1` and `stop=2`, `fun_3` should return $1^2 + 2^2 = 1 + 4 = 5$.
# If `start=1` and `stop=100`, `fun_3` should return your answer from question 2.
# I will test your function at several values of `start` and `stop`, you may assume that `stop` is always greater than `start`.
#
# ***Note:***
# This question has 1 hidden test worth 10 points.
# The autograder will not show you hidden test results until after the due date, and Gradescope will show your quiz score as `~/100` until after the due date.
#
# _Points:_ 40

# %%
def fun_3(start, stop):
    ans = 0
    for i in range(start, stop+1):
        ans += i**2
    return ans
#print(fun_3(1,100))

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!
# q3 - 1 message: fun_3 is a function (+10 points)
# q3 - 2 message: your output is correct for start=1 and stop=2 (+10 points)
# q3 - 3 message: your output is correct for start=1 and stop=100 (+10 points)

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(pdf=False, run_tests=True)
# Out:
# Running your submission against local test cases...
#
#
#
# Your submission received the following results when run against available test cases:
#
#     q1 results: All test cases passed!
#     q1 - 1 message: list_1 is the correct type (+10 pts)
#     q1 - 2 message: list_1 is the correct length (+10 pts)
#     q1 - 3 message: list_1 has all correct values (+10 pts)
#
#     q2 results: All test cases passed!
#     q2 - 1 message: int_2 is the correct type (+10 pts)
#     q2 - 2 message: int_2 is positive (+10 pts)
#     q2 - 3 message: int_2 is the correct value (+10 pts)
#
#     q3 results: All test cases passed!
#     q3 - 1 message: fun_3 is a function (+10 points)
#     q3 - 2 message: your output is correct for start=1 and stop=2 (+10 points)
#     q3 - 3 message: your output is correct for start=1 and stop=100 (+10 points)
#             <p>Your submission has been exported. Click <a href="quiz_01_2023_01_11T06_41_45_122337.zip" download="quiz_01_2023_01_11T06_41_45_122337.zip" target="_blank">here</a>
#             to download the zip file.</p>
